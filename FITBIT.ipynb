# %%
#importing Libraries
import pandas as pd
import numpy as np

# %%
#reading data
data=pd.read_csv("FitBit data.csv")

# %%
data.head(10)
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366    3/25/2016       11004           7.11             7.11
# 1  1503960366    3/26/2016       17609          11.55            11.55
# 2  1503960366    3/27/2016       12736           8.53             8.53
# 3  1503960366    3/28/2016       13231           8.93             8.93
# 4  1503960366    3/29/2016       12041           7.85             7.85
# 5  1503960366    3/30/2016       10970           7.16             7.16
# 6  1503960366    3/31/2016       12256           7.86             7.86
# 7  1503960366     4/1/2016       12262           7.87             7.87
# 8  1503960366     4/2/2016       11248           7.25             7.25
# 9  1503960366     4/3/2016       10016           6.37             6.37
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                2.57                      0.46
# ...

# %%
#cheacking for null values
data.isnull().sum()
# Out:
# Id                          0
# ActivityDate                0
# TotalSteps                  0
# TotalDistance               0
# TrackerDistance             0
# LoggedActivitiesDistance    0
# VeryActiveDistance          0
# ModeratelyActiveDistance    0
# LightActiveDistance         0
# SedentaryActiveDistance     0
# VeryActiveMinutes           0
# FairlyActiveMinutes         0
# LightlyActiveMinutes        0
# SedentaryMinutes            0
# Calories                    0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 457 entries, 0 to 456
# Data columns (total 15 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Id                        457 non-null    int64
#  1   ActivityDate              457 non-null    object
#  2   TotalSteps                457 non-null    int64
#  3   TotalDistance             457 non-null    float64
#  4   TrackerDistance           457 non-null    float64
#  5   LoggedActivitiesDistance  457 non-null    float64
#  6   VeryActiveDistance        457 non-null    float64
#  7   ModeratelyActiveDistance  457 non-null    float64
#  8   LightActiveDistance       457 non-null    float64
#  9   SedentaryActiveDistance   457 non-null    float64
#  10  VeryActiveMinutes         457 non-null    int64
#  11  FairlyActiveMinutes       457 non-null    int64
#  12  LightlyActiveMinutes      457 non-null    int64
# ...

# %%
data.tail()
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 452  8877689391     4/8/2016       23014      20.389999        20.389999
# 453  8877689391     4/9/2016       16470       8.070000         8.070000
# 454  8877689391    4/10/2016       28497      27.530001        27.530001
# 455  8877689391    4/11/2016       10622       8.060000         8.060000
# 456  8877689391    4/12/2016        2350       1.780000         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 452                       0.0               11.10                      0.63
# 453                       0.0                0.00                      0.02
# 454                       0.0               21.92                      1.12
# 455                       0.0                1.47                      0.15
# 456                       0.0                0.00                      0.00
#
# ...

# %%
#unique data 
data.Id.unique()
# Out:
# array([1503960366, 1624580081, 1644430081, 1844505072, 1927972279,
#        2022484408, 2026352035, 2320127002, 2347167796, 2873212765,
#        2891001357, 3372868164, 3977333714, 4020332650, 4057192912,
#        4319703577, 4388161847, 4445114986, 4558609924, 4702921684,
#        5553957443, 5577150313, 6117666160, 6290855005, 6391747486,
#        6775888955, 6962181067, 7007744171, 7086361926, 8053475328,
#        8253242879, 8378563200, 8583815059, 8792009665, 8877689391],
#       dtype=int64)

# %%
df=data.copy()

# %%
df.head()
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366    3/25/2016       11004           7.11             7.11
# 1  1503960366    3/26/2016       17609          11.55            11.55
# 2  1503960366    3/27/2016       12736           8.53             8.53
# 3  1503960366    3/28/2016       13231           8.93             8.93
# 4  1503960366    3/29/2016       12041           7.85             7.85
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                2.57                      0.46
# 1                       0.0                6.92                      0.73
# 2                       0.0                4.66                      0.16
# 3                       0.0                3.19                      0.79
# 4                       0.0                2.16                      1.09
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# ...

# %%
# converting data to datetime
df["ActivityDate"]=pd.to_datetime(df["ActivityDate"])

# %%
df.head()
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366   2016-03-25       11004           7.11             7.11
# 1  1503960366   2016-03-26       17609          11.55            11.55
# 2  1503960366   2016-03-27       12736           8.53             8.53
# 3  1503960366   2016-03-28       13231           8.93             8.93
# 4  1503960366   2016-03-29       12041           7.85             7.85
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                2.57                      0.46
# 1                       0.0                6.92                      0.73
# 2                       0.0                4.66                      0.16
# 3                       0.0                3.19                      0.79
# 4                       0.0                2.16                      1.09
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# ...

# %%
#extracting date,week and year 
df["year"]=df["ActivityDate"].dt.year
df["date"]=df["ActivityDate"].dt.date
df["week"]=df["ActivityDate"].dt.week

# %%
date.head()
# Out:
# 0    2016
# 1    2016
# 2    2016
# 3    2016
# 4    2016
# Name: ActivityDate, dtype: int64

# %%
df["month"]=df["ActivityDate"].dt.month

# %%
df.head()
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366   2016-03-25       11004           7.11             7.11
# 1  1503960366   2016-03-26       17609          11.55            11.55
# 2  1503960366   2016-03-27       12736           8.53             8.53
# 3  1503960366   2016-03-28       13231           8.93             8.93
# 4  1503960366   2016-03-29       12041           7.85             7.85
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                2.57                      0.46
# 1                       0.0                6.92                      0.73
# 2                       0.0                4.66                      0.16
# 3                       0.0                3.19                      0.79
# 4                       0.0                2.16                      1.09
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# ...

# %%
#plotting box-plot
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(20,8))
sns.boxplot(x=df.year ,y=df.Calories)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 457 entries, 0 to 456
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Id                        457 non-null    int64
#  1   ActivityDate              457 non-null    datetime64[ns]
#  2   TotalSteps                457 non-null    int64
#  3   TotalDistance             457 non-null    float64
#  4   TrackerDistance           457 non-null    float64
#  5   LoggedActivitiesDistance  457 non-null    float64
#  6   VeryActiveDistance        457 non-null    float64
#  7   ModeratelyActiveDistance  457 non-null    float64
#  8   LightActiveDistance       457 non-null    float64
#  9   SedentaryActiveDistance   457 non-null    float64
#  10  VeryActiveMinutes         457 non-null    int64
#  11  FairlyActiveMinutes       457 non-null    int64
#  12  LightlyActiveMinutes      457 non-null    int64
# ...

# %%
df.ActivityDate.dt.day_name
# Out:
# <bound method PandasDelegate._add_delegate_accessors.<locals>._create_delegator_method.<locals>.f of <pandas.core.indexes.accessors.DatetimeProperties object at 0x000001E3BF786E80>>

# %%
df_copy=data.copy()

# %%
date_DF=df.ActivityDate.dt.date

# %%
date_DF.astype(str)
# Out:
# 0      2016-03-25
# 1      2016-03-26
# 2      2016-03-27
# 3      2016-03-28
# 4      2016-03-29
#           ...
# 452    2016-04-08
# 453    2016-04-09
# 454    2016-04-10
# 455    2016-04-11
# 456    2016-04-12
# Name: ActivityDate, Length: 457, dtype: object

# %%
for i in df_copy.ActivityDate:
    i.split("-")
    print(i[-4:])
# Out:
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# 2016
# ...

# %%
#creating year column
df["year"]=df["ActivityDate"].dt.year

# %%
df.year
# Out:
# 0      2016
# 1      2016
# 2      2016
# 3      2016
# 4      2016
#        ...
# 452    2016
# 453    2016
# 454    2016
# 455    2016
# 456    2016
# Name: year, Length: 457, dtype: int64

# %%
#creating day column
df["day"]=df.ActivityDate.dt.day_name()

# %%
df.head()
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366   2016-03-25       11004           7.11             7.11
# 1  1503960366   2016-03-26       17609          11.55            11.55
# 2  1503960366   2016-03-27       12736           8.53             8.53
# 3  1503960366   2016-03-28       13231           8.93             8.93
# 4  1503960366   2016-03-29       12041           7.85             7.85
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                2.57                      0.46
# 1                       0.0                6.92                      0.73
# 2                       0.0                4.66                      0.16
# 3                       0.0                3.19                      0.79
# 4                       0.0                2.16                      1.09
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# ...

# %%
df["Day"]=df.ActivityDate.dt.day

# %%
df=df.rename(columns={"day":"day_name"})

# %%
df.head()
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366   2016-03-25       11004           7.11             7.11
# 1  1503960366   2016-03-26       17609          11.55            11.55
# 2  1503960366   2016-03-27       12736           8.53             8.53
# 3  1503960366   2016-03-28       13231           8.93             8.93
# 4  1503960366   2016-03-29       12041           7.85             7.85
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                2.57                      0.46
# 1                       0.0                6.92                      0.73
# 2                       0.0                4.66                      0.16
# 3                       0.0                3.19                      0.79
# 4                       0.0                2.16                      1.09
#
#    LightActiveDistance  SedentaryActiveDistance  ...  FairlyActiveMinutes  \
# ...

# %%
#droping some columns
df=df.drop(["date","ActivityDate"],axis=1)

# %%
df=df.drop("TrackerDistance",axis=1)

# %%
df.head()
# Out:
#            Id  TotalSteps  TotalDistance  LoggedActivitiesDistance  \
# 0  1503960366       11004           7.11                       0.0
# 1  1503960366       17609          11.55                       0.0
# 2  1503960366       12736           8.53                       0.0
# 3  1503960366       13231           8.93                       0.0
# 4  1503960366       12041           7.85                       0.0
#
#    VeryActiveDistance  ModeratelyActiveDistance  LightActiveDistance  \
# 0                2.57                      0.46                 4.07
# 1                6.92                      0.73                 3.91
# 2                4.66                      0.16                 3.71
# 3                3.19                      0.79                 4.95
# 4                2.16                      1.09                 4.61
#
#    SedentaryActiveDistance  VeryActiveMinutes  FairlyActiveMinutes  \
# 0                      0.0                 33                   12
# ...

# %%
sns.scatterplot(x=df.TotalSteps,y=-df.Calories)

# %%
plt.figure(figsize=(10,7))
sns.boxplot(x=df.day_name,y=df.Calories)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 457 entries, 0 to 456
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Id                        457 non-null    int64
#  1   TotalSteps                457 non-null    int64
#  2   TotalDistance             457 non-null    float64
#  3   LoggedActivitiesDistance  457 non-null    float64
#  4   VeryActiveDistance        457 non-null    float64
#  5   ModeratelyActiveDistance  457 non-null    float64
#  6   LightActiveDistance       457 non-null    float64
#  7   SedentaryActiveDistance   457 non-null    float64
#  8   VeryActiveMinutes         457 non-null    int64
#  9   FairlyActiveMinutes       457 non-null    int64
#  10  LightlyActiveMinutes      457 non-null    int64
#  11  SedentaryMinutes          457 non-null    int64
#  12  Calories                  457 non-null    int64
# ...

# %%
plt.scatter(x=df.Calories,y=df.VeryActiveDistance)

# %%
plt.scatter(x=df.Calories,y=df.SedentaryMinutes)

# %%
df.columns
# Out:
# Index(['Id', 'TotalSteps', 'TotalDistance', 'LoggedActivitiesDistance',
#        'VeryActiveDistance', 'ModeratelyActiveDistance', 'LightActiveDistance',
#        'SedentaryActiveDistance', 'VeryActiveMinutes', 'FairlyActiveMinutes',
#        'LightlyActiveMinutes', 'SedentaryMinutes', 'Calories', 'year', 'week',
#        'month', 'day_name', 'Day'],
#       dtype='object')

# %%
col_select = ['Calories','VeryActiveMinutes','FairlyActiveMinutes','LightlyActiveMinutes','SedentaryMinutes']

# %%
#plotting lineplot
wide_df = df[col_select]

# figure size

plt.figure(figsize=(15,8))

# timeseries plot using lineplot
ax = sns.lineplot(data=wide_df)

ax.set_title('Un-normalized value of calories and different activities based on activity minutes')
# Out:
# Text(0.5, 1.0, 'Un-normalized value of calories and different activities based on activity minutes')

# %%
tol_dis=['TotalDistance', 'LoggedActivitiesDistance',
       'VeryActiveDistance', 'ModeratelyActiveDistance', 'LightActiveDistance',
       'SedentaryActiveDistance']

# %%
plt.figure(figsize=(15,8))
sns.lineplot(data=df[tol_dis])

# %%
#plotting boxen plot
sns.sub
sns.boxenplot(x=df["day_name"],y=df["Calories"])

# %%
plt.figure(figsize=(12,7))
plt.subplot(1,2,1)
sns.scatterplot(x=df["Calories"],y=df["TotalSteps"])
plt.subplot(1,2,2)
sns.scatterplot(x=df["Calories"],y=df["TotalDistance"])

# %%
plt.figure(figsize=(10,5))
ax=sns.barplot(x=df.day_name,y=df.TotalDistance)
ax=sns.lineplot(x=df.day_name,y=df.TotalDistance)

# %%
plt.figure(figsize=(10,5))
sns.swarmplot(x=df.day_name,y=df.TotalDistance)

# %%
plt.figure(figsize=(10,5))

# %%
sns.swarmplot(x=df.week,y=df.TotalDistance)

# %%
plt.figure(figsize=(15,8))
ax=sns.boxplot(x=df.Day,y=df.Calories,)
sns.lineplot(x=df.Day,y=df.Calories)
